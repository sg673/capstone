# %%
import pandas as pd

def import_file(file_name, file_type):
    """
    Imports a CSV file into a pandas DataFrame.

    Args:
        file_name (str): The name of the CSV file to import.
        file_type (str): The type of data to import (raw, processed, etc.)

    Returns:
        pd.DataFrame: The DataFrame containing the data from the CSV file.
    """
    return pd.read_csv("../data/" + file_type + "/" + file_name)

airports_df = import_file("airports.csv", "raw")

# %%
# Filter American airports
us_airports_df = airports_df[airports_df['country'] == 'United States'].sort_values(by="iata")
us_airports_df
# Out:
#         id                                 name           city        country  \
# 6042  8252        Apalachicola Regional Airport   Apalachicola  United States
# 6512  9225                       Andrau Airpark        Houston  United States
# 4085  4355  Lehigh Valley International Airport      Allentown  United States
# 3518  3718             Abilene Regional Airport        Abilene  United States
# 5415  7177                       Ambler Airport         Ambler  United States
# ...    ...                                  ...            ...            ...
# 6399  8931               Longview Ranch Airport       Longview  United States
# 6398  8928             Windom Municipal Airport         Windom  United States
# 3457  3657               Emanuel County Airport  Santa Barbara  United States
# 6574  9409         Desert Aire Regional Airport        Mattawa  United States
# 6205  8542       Lorain County Regional Airport  Lorain-Elyria  United States
#
#      iata  icao        lat         lon   alt  tz dst             timezone  \
# 6042  AAF  KAAF  29.727501  -85.027496    20  -5   A     America/New_York
# 6512  AAP  KAAP  29.722500  -95.588303    79  -6   A      America/Chicago
# 4085  ABE  KABE  40.652100  -75.440804   393  -5   A     America/New_York
# 3518  ABI  KABI  32.411301  -99.681900  1791  -6   A      America/Chicago
# 5415  ABL  PAFM  67.106300 -157.856989   334  -9   A    America/Anchorage
# ...   ...   ...        ...         ...   ...  ..  ..                  ...
# 6399   \N  OG39  44.661701 -119.652000  2080  -8   A  America/Los_Angeles
# 6398   \N  KMWM  43.913399  -95.109398  1410  -6   A      America/Chicago
# 3457   \N  KSBO  32.609100  -82.369904   327  -5   A     America/New_York
# 6574   \N  KM94  46.687401 -119.920998   586  -8   A  America/Los_Angeles
# 6205   \N  KLPR  41.344299  -82.177597   793  -5   A     America/New_York
#
#          type       source
# 6042  airport  OurAirports
# 6512  airport  OurAirports
# 4085  airport  OurAirports
# 3518  airport  OurAirports
# 5415  airport  OurAirports
# ...       ...          ...
# 6399  airport  OurAirports
# 6398  airport  OurAirports
# 3457  airport  OurAirports
# 6574  airport  OurAirports
# 6205  airport  OurAirports
#
# [1512 rows x 14 columns]

# %%
# Remove unnecessary columns
us_airports_df = us_airports_df[['id', 'name', 'city', 'country','iata','lat','lon','alt']]
us_airports_df
# Out:
#         id                                 name           city        country  \
# 6042  8252        Apalachicola Regional Airport   Apalachicola  United States
# 6512  9225                       Andrau Airpark        Houston  United States
# 4085  4355  Lehigh Valley International Airport      Allentown  United States
# 3518  3718             Abilene Regional Airport        Abilene  United States
# 5415  7177                       Ambler Airport         Ambler  United States
# ...    ...                                  ...            ...            ...
# 6399  8931               Longview Ranch Airport       Longview  United States
# 6398  8928             Windom Municipal Airport         Windom  United States
# 3457  3657               Emanuel County Airport  Santa Barbara  United States
# 6574  9409         Desert Aire Regional Airport        Mattawa  United States
# 6205  8542       Lorain County Regional Airport  Lorain-Elyria  United States
#
#      iata        lat         lon   alt
# 6042  AAF  29.727501  -85.027496    20
# 6512  AAP  29.722500  -95.588303    79
# 4085  ABE  40.652100  -75.440804   393
# 3518  ABI  32.411301  -99.681900  1791
# 5415  ABL  67.106300 -157.856989   334
# ...   ...        ...         ...   ...
# 6399   \N  44.661701 -119.652000  2080
# 6398   \N  43.913399  -95.109398  1410
# 3457   \N  32.609100  -82.369904   327
# 6574   \N  46.687401 -119.920998   586
# 6205   \N  41.344299  -82.177597   793
#
# [1512 rows x 8 columns]

# %%
us_airports_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 6042 to 6205
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1512 non-null   int64
#  1   name     1512 non-null   object
#  2   city     1512 non-null   object
#  3   country  1512 non-null   object
#  4   iata     1512 non-null   object
#  5   lat      1512 non-null   float64
#  6   lon      1512 non-null   float64
#  7   alt      1512 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 106.3+ KB

# %%
#replace all \N with NaN
us_airports_df = us_airports_df.replace('\\N', pd.NA)

#Count how many nulls in each column (nulls are represented by \N in dataset)
us_airports_df.isnull().sum()
# Out:
# id           0
# name         0
# city         0
# country      0
# iata       261
# lat          0
# lon          0
# alt          0
# dtype: int64

# %%
# Remove all rows that contain null values
us_airports_df = us_airports_df.dropna()
us_airports_df.isnull().sum()
# Out:
# id         0
# name       0
# city       0
# country    0
# iata       0
# lat        0
# lon        0
# alt        0
# dtype: int64

# %%
us_airports_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251 entries, 6042 to 7105
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1251 non-null   int64
#  1   name     1251 non-null   object
#  2   city     1251 non-null   object
#  3   country  1251 non-null   object
#  4   iata     1251 non-null   object
#  5   lat      1251 non-null   float64
#  6   lon      1251 non-null   float64
#  7   alt      1251 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 88.0+ KB

# %%
delay_df = import_file("Airline_Delay_Cause.csv", "raw")
delay_df = delay_df.sort_values(["year", "month", "carrier", "airport"])
delay_df.head()
# Out:
#         year  month carrier            carrier_name airport  \
# 405358  2003      6      AA  American Airlines Inc.     ABQ
# 405359  2003      6      AA  American Airlines Inc.     ANC
# 405360  2003      6      AA  American Airlines Inc.     ATL
# 405361  2003      6      AA  American Airlines Inc.     AUS
# 405362  2003      6      AA  American Airlines Inc.     BDL
#
#                                              airport_name  arr_flights  \
# 405358  Albuquerque, NM: Albuquerque International Sun...        307.0
# 405359  Anchorage, AK: Ted Stevens Anchorage Internati...         90.0
# 405360  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        752.0
# 405361       Austin, TX: Austin - Bergstrom International        842.0
# 405362                Hartford, CT: Bradley International        383.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 405358       56.0       14.68       10.79  ...         1.48              9.96
# 405359       27.0        7.09        2.00  ...         0.00              7.16
# 405360      186.0       33.99       27.82  ...         1.90             17.53
# 405361      174.0       60.24       20.54  ...         4.69             40.75
# 405362       55.0       14.90        8.91  ...         0.00             16.61
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 405358            1.0           1.0     2530.0          510.0          621.0
# 405359            0.0           0.0     1390.0          271.0           83.0
# 405360            5.0           0.0     8314.0         1367.0         1722.0
# 405361            9.0           1.0     8344.0         3040.0         1032.0
# 405362            0.0           0.0     3137.0          815.0          574.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 405358      676.0            25.0                698.0
# 405359      581.0             0.0                455.0
# 405360     3817.0           139.0               1269.0
# 405361     1835.0           115.0               2322.0
# 405362      555.0             0.0               1193.0
#
# [5 rows x 21 columns]

# %%
#compare airports in airports and in late
airports_late = us_airports_df[us_airports_df['iata'].isin(delay_df['airport'])]
airports_late
# Out:
#         id                                  name         city        country  \
# 4085  4355   Lehigh Valley International Airport    Allentown  United States
# 3518  3718              Abilene Regional Airport      Abilene  United States
# 3805  4019     Albuquerque International Sunport  Albuquerque  United States
# 4406  5714             Aberdeen Regional Airport     Aberdeen  United States
# 4407  5715    Southwest Georgia Regional Airport       Albany  United States
# ...    ...                                   ...          ...            ...
# 4086  4356   Northwest Arkansas Regional Airport  Bentonville  United States
# 5183  6803                       Yakutat Airport      Yakutat  United States
# 4470  5779  Yakima Air Terminal McAllister Field       Yakima  United States
# 3681  3881    Youngstown Warren Regional Airport   Youngstown  United States
# 3396  3596  Yuma MCAS/Yuma International Airport         Yuma  United States
#
#      iata        lat         lon   alt
# 4085  ABE  40.652100  -75.440804   393
# 3518  ABI  32.411301  -99.681900  1791
# 3805  ABQ  35.040199 -106.609001  5355
# 4406  ABR  45.449100  -98.421799  1302
# 4407  ABY  31.535500  -84.194504   197
# ...   ...        ...         ...   ...
# 4086  XNA  36.281898  -94.306801  1287
# 5183  YAK  59.503300 -139.660004    33
# 4470  YKM  46.568199 -120.543999  1099
# 3681  YNG  41.260700  -80.679100  1192
# 3396  YUM  32.656601 -114.606003   213
#
# [412 rows x 8 columns]
